# %% [markdown]
# ## 영등포구 소재 지하철역

# %%
import folium
import pandas as pd

# %%
df = pd.read_csv('data/영등포소재 지하철역2.csv')
df
# Out:
#        이름                             주소         위도          경도
# 0    영등포역  서울특별시 영등포구 경인로 지하843 (영등포동3가)  37.516463  126.906659
# 1    신도림역       서울특별시 구로구 경인로 625 (신도림동)  37.507084  126.884719
# 2     당산역     서울특별시 영등포구 당산로 229 (당산동6가)  37.534957  126.902731
# 3    여의도역   서울특별시 영등포구 여의나루로 지하40 (여의도동)  37.521842  126.924485
# 4  영등포구청역   서울특별시 영등포구 당산로 지하121 (당산동3가)  37.525700  126.896627

# %%
map = folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=14)  # Center position
for i in df.index:
    folium.Marker(
        location=[df.위도[i], df.경도[i]],       
        tooltip=df.이름[i],
        popup=folium.Popup(df.주소[i], max_width=200)
    ).add_to(map)

title_html = '<h3 align="center" style="font-size:20px">영등포소재 주요 지하철역</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ce3d6490eb0c79631f12f7f399623c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;영등포소재 주요 지하철역&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ce3d6490eb0c79631f12f7f399623c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ce3d6490eb0c79631f12f7f399623c3 = L.map(
#                 &quot;map_7ce3d6490eb0c79631f12f7f399623c3&quot;,
#                 {
#                     center: [37.52120913312664, 126.9030439466804],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fcfd4dcd55fd4e39ee8616b016204a38 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7ce3d6490eb0c79631f12f7f399623c3);
#
#
#             var marker_8022dfc5ca765ad363a992704f743643 = L.marker(
#                 [37.5164625580995, 126.906658750671],
#                 {}
#             ).addTo(map_7ce3d6490eb0c79631f12f7f399623c3);
#
#
#         var popup_36e4d25fd681c62901e5ab5fc22557cd = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_706bb63bb63b9bb2b1d97162b8298412 = $(`&lt;div id=&quot;html_706bb63bb63b9bb2b1d97162b8298412&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 경인로 지하843 (영등포동3가)&lt;/div&gt;`)[0];
#                 popup_36e4d25fd681c62901e5ab5fc22557cd.setContent(html_706bb63bb63b9bb2b1d97162b8298412);
#
#
#
#         marker_8022dfc5ca765ad363a992704f743643.bindPopup(popup_36e4d25fd681c62901e5ab5fc22557cd)
#         ;
#
#
#
#
#             marker_8022dfc5ca765ad363a992704f743643.bindTooltip(
#                 `&lt;div&gt;
#                      영등포역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d5a475df459bec3927b64482478bdd2c = L.marker(
#                 [37.5070842748567, 126.884718686628],
#                 {}
#             ).addTo(map_7ce3d6490eb0c79631f12f7f399623c3);
#
#
#         var popup_30eedac71f48697095b6dc969b173cc3 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_40f0b81bb61d8b55edecb63977f1912d = $(`&lt;div id=&quot;html_40f0b81bb61d8b55edecb63977f1912d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 구로구 경인로 625 (신도림동)&lt;/div&gt;`)[0];
#                 popup_30eedac71f48697095b6dc969b173cc3.setContent(html_40f0b81bb61d8b55edecb63977f1912d);
#
#
#
#         marker_d5a475df459bec3927b64482478bdd2c.bindPopup(popup_30eedac71f48697095b6dc969b173cc3)
#         ;
#
#
#
#
#             marker_d5a475df459bec3927b64482478bdd2c.bindTooltip(
#                 `&lt;div&gt;
#                      신도림역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8984550269f4b33bd45b4b31ec33d511 = L.marker(
#                 [37.534956866618, 126.90273071003],
#                 {}
#             ).addTo(map_7ce3d6490eb0c79631f12f7f399623c3);
#
#
#         var popup_c49d7d453e1bfd7c1f02422520f702bc = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_8eeb08201e919eaf49bd677da4fa2f46 = $(`&lt;div id=&quot;html_8eeb08201e919eaf49bd677da4fa2f46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 당산로 229 (당산동6가)&lt;/div&gt;`)[0];
#                 popup_c49d7d453e1bfd7c1f02422520f702bc.setContent(html_8eeb08201e919eaf49bd677da4fa2f46);
#
#
#
#         marker_8984550269f4b33bd45b4b31ec33d511.bindPopup(popup_c49d7d453e1bfd7c1f02422520f702bc)
#         ;
#
#
#
#
#             marker_8984550269f4b33bd45b4b31ec33d511.bindTooltip(
#                 `&lt;div&gt;
#                      당산역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7ddc2daead1d19a491c7ab1d01cadf73 = L.marker(
#                 [37.5218423045786, 126.924484687694],
#                 {}
#             ).addTo(map_7ce3d6490eb0c79631f12f7f399623c3);
#
#
#         var popup_8e6f5ff7bbe3731bee334372c3083176 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_8cb485473224b503087f0f8bc395c1f7 = $(`&lt;div id=&quot;html_8cb485473224b503087f0f8bc395c1f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 여의나루로 지하40 (여의도동)&lt;/div&gt;`)[0];
#                 popup_8e6f5ff7bbe3731bee334372c3083176.setContent(html_8cb485473224b503087f0f8bc395c1f7);
#
#
#
#         marker_7ddc2daead1d19a491c7ab1d01cadf73.bindPopup(popup_8e6f5ff7bbe3731bee334372c3083176)
#         ;
#
#
#
#
#             marker_7ddc2daead1d19a491c7ab1d01cadf73.bindTooltip(

# %%
df['color'] = ['red', 'blue', 'green', 'violet', 'orange']
df
# Out:
#        이름                             주소         위도          경도   color
# 0    영등포역  서울특별시 영등포구 경인로 지하843 (영등포동3가)  37.516463  126.906659     red
# 1    신도림역       서울특별시 구로구 경인로 625 (신도림동)  37.507084  126.884719    blue
# 2     당산역     서울특별시 영등포구 당산로 229 (당산동6가)  37.534957  126.902731   green
# 3    여의도역   서울특별시 영등포구 여의나루로 지하40 (여의도동)  37.521842  126.924485  violet
# 4  영등포구청역   서울특별시 영등포구 당산로 지하121 (당산동3가)  37.525700  126.896627  orange

# %%
map = folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=14)  # Center position
for i in df.index:
    folium.Circle(
        location=[df.위도[i], df.경도[i]],       
        tooltip=df.이름[i],
        popup=folium.Popup(df.주소[i], max_width=200),
        radius=100, color=df.color[i], fill=True
    ).add_to(map)
    folium.map.Marker(
        location=[df.위도[i], df.경도[i]], 
        icon = folium.DivIcon(icon_size=(80,20), icon_anchor=(20,0),
                    html=f'<span style="font-size: 10pt">{df.이름[i]}</span>')
    ).add_to(map)

folium.Marker(
    location=[df.위도.mean(), df.경도.mean()],
    icon=folium.CustomIcon('data/pushpin.png', icon_size=(30,30))
).add_to(map)

title_html = '<h3 align="center" style="font-size:20px">영등포소재 주요 지하철역</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0145c78a5dddb53c6b7cf0957f02ba39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;영등포소재 주요 지하철역&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0145c78a5dddb53c6b7cf0957f02ba39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0145c78a5dddb53c6b7cf0957f02ba39 = L.map(
#                 &quot;map_0145c78a5dddb53c6b7cf0957f02ba39&quot;,
#                 {
#                     center: [37.52120913312664, 126.9030439466804],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff3c678f0734d6b41ce336d85ce39a53 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0145c78a5dddb53c6b7cf0957f02ba39);
#
#
#             var circle_6c7bca80261e853dae97da6bfe981443 = L.circle(
#                 [37.5164625580995, 126.906658750671],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0145c78a5dddb53c6b7cf0957f02ba39);
#
#
#         var popup_bc0e45bd221b4fb97a75e40adc98bf0c = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_645505d0aff030409e1459655c94310e = $(`&lt;div id=&quot;html_645505d0aff030409e1459655c94310e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 경인로 지하843 (영등포동3가)&lt;/div&gt;`)[0];
#                 popup_bc0e45bd221b4fb97a75e40adc98bf0c.setContent(html_645505d0aff030409e1459655c94310e);
#
#
#
#         circle_6c7bca80261e853dae97da6bfe981443.bindPopup(popup_bc0e45bd221b4fb97a75e40adc98bf0c)
#         ;
#
#
#
#
#             circle_6c7bca80261e853dae97da6bfe981443.bindTooltip(
#                 `&lt;div&gt;
#                      영등포역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ec76265ca500b0c2ae47af3f9aa1e9b1 = L.marker(
#                 [37.5164625580995, 126.906658750671],
#                 {}
#             ).addTo(map_0145c78a5dddb53c6b7cf0957f02ba39);
#
#
#             var div_icon_43af73e03f8db944973ad0746cf5090e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan style=\&quot;font-size: 10pt\&quot;\u003e\uc601\ub4f1\ud3ec\uc5ed\u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [20, 0], &quot;iconSize&quot;: [80, 20]});
#             marker_ec76265ca500b0c2ae47af3f9aa1e9b1.setIcon(div_icon_43af73e03f8db944973ad0746cf5090e);
#
#
#             var circle_28f0afccc96103fc905cb641158528d6 = L.circle(
#                 [37.5070842748567, 126.884718686628],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0145c78a5dddb53c6b7cf0957f02ba39);
#
#
#         var popup_38abc76f588d85cd86de8c3e99f2b8be = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_5bf52947442d54872bfbf9f5af6ff6a0 = $(`&lt;div id=&quot;html_5bf52947442d54872bfbf9f5af6ff6a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 구로구 경인로 625 (신도림동)&lt;/div&gt;`)[0];
#                 popup_38abc76f588d85cd86de8c3e99f2b8be.setContent(html_5bf52947442d54872bfbf9f5af6ff6a0);
#
#
#
#         circle_28f0afccc96103fc905cb641158528d6.bindPopup(popup_38abc76f588d85cd86de8c3e99f2b8be)
#         ;
#
#
#
#
#             circle_28f0afccc96103fc905cb641158528d6.bindTooltip(
#                 `&lt;div&gt;
#                      신도림역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_67c8a6dbb2f92e7d23584cd67ee1d8d6 = L.marker(
#                 [37.5070842748567, 126.884718686628],
#                 {}
#             ).addTo(map_0145c78a5dddb53c6b7cf0957f02ba39);
#
#
#             var div_icon_299eefa6594b472b5d8a700f678ae153 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan style=\&q
